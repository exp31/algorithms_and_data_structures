# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Part 1:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 2:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %%
# Your answer here

# %% [markdown]
# we are given the root of a binary tree and needs to check if there are any duplicate values within the tree. If a duplicate is found return the value of the duplicate thats closest to the root. If there are no duplicates return -1

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %%
# Your answer here
#root = [7, 5, 10, 3, 5, null, 10]
#output = 10

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
# Your answer here
## Definition for a binary tree node.
class TreeNode(object):
     def __init__(self, val = 0, left = None, right = None):
         self.val = val
         self.left = left
         self.right = right

# def is_duplicate(root: TreeNode) --> int: 
# TO DO
# def is_duplicate(root: TreeNode):
    # Store and track values seen and any duplicates 
    seen_values = set()
    duplicates = []

    # Define helper function 
    def inorder_traversal(current_node, seen_values, duplicates):

        if current_node:
            # Start by traversing the left subtree
            inorder_traversal(current_node.left, seen_values, duplicates)

            # Check if the current node's value is a duplicate by comparing it to seen values
            if current_node.val in seen_values:
                duplicates.append(current_node.val)  # If there is a duplicate value, append it to the list duplicates
            else:
                seen_values.add(current_node.val)  # Add the current value to the set of seen values 

            # Traverse the right subtree
            inorder_traversal(current_node.right, seen_values, duplicates)

    # Start inorder traversal
    inorder_traversal(root, seen_values, duplicates)

    # Return the list of duplicates or -1 if no duplicates are found
    if duplicates: 
        return duplicates
    else:
        print([-1])

# %% [markdown]
# -   Explain why their solution works in your own words.

# %%
# Your answer here

# %% [markdown]
# Question: Under your partner's solution, what will be the actual output and the desired output when the input is [1,2,3,4,5,3,7,4]?
#     root = TreeNode(1)
#     root.left = TreeNode(2)
#     root.right = TreeNode(3)
#     root.left.left = TreeNode(4)
#     root.left.right = TreeNode(5)
#     root.right.left = TreeNode(3)
#     root.right.right = TreeNode(7)
#     root.left.left.left = TreeNode(4)
#
#     Answer: Actual output: [3,4]. The desired output is 3

# %% [markdown]
# Question: Also, you stated that it could be possible to return the first duplicate instead of completing a full traversal. With the same example above, what will be the actual output and the desired output if you return the first duplicate and terminate the program?
#
#     Answer: Actual output: 4. The desired output is 3

# %% [markdown]
# first it defines treenode class to represent each node in the binary tree with a value and pointers to the left and right children the is_duplicate function checks for duplicate values in the tree using a set to track values that have already been encountered and a list to store any duplicates it performs an in-order traversal of the tree visiting the left subtree the current node and then the right subtree during this traversal it checks if the current node’s value is already in the set of seen values if it is the value is added to the duplicates list if the value hasn't been seen before it is added to the set of seen values after the traversal is complete the function checks if any duplicates were found if duplicates are found it returns the list of duplicates if no duplicates are found it returns [-1]

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %%
# Your answer here

# %% [markdown]
# time complexity is O(n) because the algorithm visits each node once during the in order traversal where n is the number of nodes in the tree. The space complexity is O(n) due to the use of a set to store seen values and the recursion stack

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %%
# Your answer here
# old answer: solution could just return the first duplicate found instead of continuing to traversal since the question asks for the closest duplicate to the root
# replace print([-1]) with return -1

# %% [markdown]
# ## Part 3:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %%
# Your answer here

# %% [markdown]
# For Assignment 1 I was given a list of numbers from 0 to n where n is the length of the list. The task was to find the missing numbers in the range [0, n] and return them as a list. If no numbers were missing = the function should return -1. My solution involved converting the input list into a set for fast lookups and storing the length of the list as n to define the range. I then created an empty list to store missing numbers and looped through the range from 0 to n. For each number I checked if it was in the input list using the set for fast lookup and if missing = added it to the list. For time complexity I explained that the loop runs through the range [0, n] so the time complexity is O(n). The check for each number in the set is O(1) on average making the overall time complexity O(n). Space complexity is O(n) because I used a set and a list to store numbers.
#
# For an alternative solution, I suggested comparing the sum of the numbers in the list with the sum of numbers from 0 to n. If the sums are different, I would identify the missing numbers. This method might be less efficient than using a set for lookups.
#
# In my partners solution above for the binary tree I suggested stopping after the first duplicate is found to improve efficiency.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
